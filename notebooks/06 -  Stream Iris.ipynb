# %% [markdown]
# # Stream IRIS testing data

# %%
import time
import json
from uuid import uuid4
from confluent_kafka import Producer

# %% [markdown]
# ## Connect to kafka broker and stream the csv file

# %%
def delivery_report(errmsg, msg):
    if errmsg is not None:
        print("Delivery failed for Message: {} : {}".format(msg.key(), errmsg))
    return
    print('Message: {} successfully produced to Topic: {} Partition: [{}] at offset {}'.format(
        msg.key(), msg.topic(), msg.partition(), msg.offset()))

# %%
kafka_topic_name = "iris_topic"

conf = {
'bootstrap.servers' : 'kafka:9092'
}

# connect to kafka
producer1 = Producer(conf)

# stream the csv file
myFile = open('Iris_features.csv')
print("The content of CSV file is:")
text_list = myFile.readlines()
for line in text_list:
    try:
        producer1.produce(topic=kafka_topic_name, key=str(uuid4()), value=line, on_delivery=delivery_report(errmsg=None,msg=line))
        producer1.flush()
    except Exception as ex:
        print("Exception happened :",ex)

myFile.close()
# Out:
# The content of CSV file is:

# %%
# %run ./consumer.py getting_started.ini iris_topic
# Out:
# Consumed event from topic iris_topic: key = e4f7323d-2969-41c6-a8d4-de0307a6f482 value = 5.7,2.5,5.0,2.0
#
# Consumed event from topic iris_topic: key = 53eb97bc-106a-4cf4-b7d6-4f5df4e1f793 value = 5.2,4.1,1.5,0.1
#
# Consumed event from topic iris_topic: key = 9aef93eb-0045-4476-aceb-933a86eda618 value = 6.1,2.8,4.0,1.3
#
# Consumed event from topic iris_topic: key = 7322c11f-3001-47f6-b1de-19a8f4025c72 value = 4.5,2.3,1.3,0.3
#
# Consumed event from topic iris_topic: key = 7b364280-6208-4923-aa72-9fdd2994e86b value = 6.5,2.8,4.6,1.5
#
# Consumed event from topic iris_topic: key = ec322242-d940-41a2-94e9-064c9adf2434 value = 5.0,3.0,1.6,0.2
#
# Consumed event from topic iris_topic: key = 37f98db5-3184-4ab8-9479-79ecd06f2f25 value = 6.4,2.8,5.6,2.2
#
# Consumed event from topic iris_topic: key = 552be57c-a3e0-4815-8d78-9f3314f6d97e value = 5.0,3.4,1.6,0.4
#
# Consumed event from topic iris_topic: key = 0704ab7e-6af1-457b-92a8-7fc8f81321ea value = 5.6,2.9,3.6,1.3
#
# Consumed event from topic iris_topic: key = 2007d1e7-5800-470c-a519-0fc32cffd8fa value = 6.9,3.1,5.4,2.1
#
# Consumed event from topic iris_topic: key = accec263-2749-47a0-9ebf-6b552203f8d0 value = 6.3,3.3,4.7,1.6
#
# Consumed event from topic iris_topic: key = 8c4250b3-bb95-4017-b4e6-034f36b3b82c value = 5.1,3.5,1.4,0.3
#
# Consumed event from topic iris_topic: key = 4cb0f662-adc2-4903-9785-272e3facb8c3 value = 5.0,2.0,3.5,1.0
#
# Consumed event from topic iris_topic: key = 9fa22729-9685-4eb2-839b-5d63d05d3213 value = 5.6,2.8,4.9,2.0
#
# Consumed event from topic iris_topic: key = 9fe3139e-120e-4a56-a9e4-16e3fd613f57 value = 5.8,2.7,5.1,1.9
#
# Consumed event from topic iris_topic: key = 5064c57d-e76f-4946-a9f4-915d70e02fa6 value = 5.1,3.4,1.5,0.2
#
# Consumed event from topic iris_topic: key = b6e2a66e-1a23-4de4-8bb1-295fcf5104a2 value = 6.2,2.2,4.5,1.5
#
# Consumed event from topic iris_topic: key = a812a81a-58c8-44e9-b1b1-4becd3f9ba2c value = 4.8,3.4,1.6,0.2
#
# Consumed event from topic iris_topic: key = a26ebaa8-e0f6-455c-a324-fe4972ce9c08 value = 7.7,3.8,6.7,2.2
#
# Consumed event from topic iris_topic: key = 49bdb509-35bf-43a3-bb93-379a9defa33f value = 6.7,3.3,5.7,2.5
#
# Consumed event from topic iris_topic: key = 2c4a2fa0-4f18-41d7-9170-ac432ee66736 value = 6.7,3.0,5.2,2.3
#
# Consumed event from topic iris_topic: key = 837ed592-fadc-4341-879b-b369e7b0103b value = 6.7,2.5,5.8,1.8
#
# Consumed event from topic iris_topic: key = fd0f7f65-e972-47b3-a6d0-139667a8e988 value = 5.8,2.7,4.1,1.0
#
# Consumed event from topic iris_topic: key = 9c7e495b-b99c-4d9d-ae29-4b5e28d6ead7 value = 6.4,2.8,5.6,2.1
#
# Consumed event from topic iris_topic: key = fbbc09ee-c7c6-465b-9dd5-aa6c99749e51 value = 6.0,2.7,5.1,1.6
#
# Consumed event from topic iris_topic: key = 1cc900c4-4f67-4656-adf8-656d695823ec value = 4.8,3.0,1.4,0.3
#
# Consumed event from topic iris_topic: key = d9c4a6f2-2c4b-4039-8557-d6fcc3601a31 value = 5.1,3.8,1.5,0.3
#
# Consumed event from topic iris_topic: key = f369a72a-1016-4fd9-bd9b-ca7c7ca7a48c value = 6.1,2.8,4.7,1.2
#
# Consumed event from topic iris_topic: key = 0526cc3a-7f39-418d-8587-7cad3fb3e383 value = 6.4,3.2,4.5,1.5
#
# Consumed event from topic iris_topic: key = 06e9c3c6-9595-44d0-a6f0-cbf1800a8ec6 value = 6.5,3.0,5.5,1.8
#
# Consumed event from topic iris_topic: key = 91fb09b7-8a53-4e53-a3aa-f5930b790412 value = 7.0,3.2,4.7,1.4
#
# Consumed event from topic iris_topic: key = 816c65ca-b1dd-4f72-94f8-1672a36c02ec value = 4.9,3.1,1.5,0.1
#
# Consumed event from topic iris_topic: key = 95708094-04e3-4456-9988-a8e02f3ed39f value = 4.9,3.1,1.5,0.2
#
# Consumed event from topic iris_topic: key = 598c55c3-67dc-4fa7-aaa5-e8e8135cce06 value = 5.7,2.6,3.5,1.0
#
# Consumed event from topic iris_topic: key = c1c26daa-e880-494e-b6b8-805d28d624ec value = 5.0,2.3,3.3,1.0
#
# Consumed event from topic iris_topic: key = 708a4a72-8d6a-44fe-8b5f-2c3e0ba8244a value = 7.7,3.0,6.1,2.3
#
# Consumed event from topic iris_topic: key = c93ba40b-265c-4c60-adde-17be2f0b3704 value = 5.8,2.7,3.9,1.2
#
# Consumed event from topic iris_topic: key = 9b90e1fe-10e7-488c-945d-c811d59481a3 value = 6.5,3.0,5.2,2.0
#
# Consumed event from topic iris_topic: key = d6fe32dc-c04b-4ec8-a0eb-6cdcbb6abda6 value = 5.7,2.5,5.0,2.0
#
# Consumed event from topic iris_topic: key = d7e09202-f861-4198-8667-2f588423dce2 value = 5.2,4.1,1.5,0.1
#
# Consumed event from topic iris_topic: key = 5d07ebbd-0eed-45b6-9469-d4eee0d48000 value = 6.1,2.8,4.0,1.3
#
# Consumed event from topic iris_topic: key = e6cba02b-ca2f-4050-ac46-bb9cc7393b09 value = 4.5,2.3,1.3,0.3
#
# Consumed event from topic iris_topic: key = 3b548771-1d32-4b5e-9ba6-5503fc57b77a value = 6.5,2.8,4.6,1.5
#
# Consumed event from topic iris_topic: key = 3e8ffe78-70f9-4d73-b34a-bbab2e82f20a value = 5.0,3.0,1.6,0.2
#
# Consumed event from topic iris_topic: key = c028f5fc-a760-49ac-b289-cb2ced05c70b value = 6.4,2.8,5.6,2.2
#
# Consumed event from topic iris_topic: key = 398797e3-8db6-4fef-bc4e-e7930d0ef85e value = 5.0,3.4,1.6,0.4
#
# Consumed event from topic iris_topic: key = 1f296bf7-75d5-4e02-811d-aa564fdfda1d value = 5.6,2.9,3.6,1.3
#
# Consumed event from topic iris_topic: key = c474b05b-a676-413e-aeb5-b881904694fd value = 6.9,3.1,5.4,2.1
#
# Consumed event from topic iris_topic: key = 8989230a-c1f4-4171-ab86-a697e7abd33e value = 6.3,3.3,4.7,1.6
#
# Consumed event from topic iris_topic: key = 9dc3a45a-a626-40dc-8a9e-250297cfdec6 value = 5.1,3.5,1.4,0.3
#
# Consumed event from topic iris_topic: key = f0a229e4-a055-4beb-b8fb-fe8afe335272 value = 5.0,2.0,3.5,1.0
#
# Consumed event from topic iris_topic: key = 8f87e6f7-8716-439e-a845-c66aa08af1cb value = 5.6,2.8,4.9,2.0
#
# Consumed event from topic iris_topic: key = 867ef53f-6e0e-438b-928d-ce506001d700 value = 5.8,2.7,5.1,1.9
#
# Consumed event from topic iris_topic: key = de05fbe2-a74f-4042-b37f-86efcf538db3 value = 5.1,3.4,1.5,0.2
#
# Consumed event from topic iris_topic: key = 5a870b06-7481-4f61-9aa9-7df82ed348ed value = 6.2,2.2,4.5,1.5
#
# Consumed event from topic iris_topic: key = a548115f-7476-4a66-89eb-783ac499430d value = 4.8,3.4,1.6,0.2
#
# Consumed event from topic iris_topic: key = 1bc8450c-ad18-4d85-a6c1-5f647fccdff3 value = 7.7,3.8,6.7,2.2
#
# Consumed event from topic iris_topic: key = de23c36b-54fd-4da6-b42a-38e4b3ab87ee value = 6.7,3.3,5.7,2.5
#
# Consumed event from topic iris_topic: key = ea3ba84a-fe7a-42a2-acfa-4b756d85aa6d value = 6.7,3.0,5.2,2.3
#
# Consumed event from topic iris_topic: key = 6306ca5c-4283-4169-a4e2-f084390f29d4 value = 6.7,2.5,5.8,1.8
#
# Consumed event from topic iris_topic: key = 72b0f135-c8c0-4306-860b-c61dc87d7eb7 value = 5.8,2.7,4.1,1.0
#
# Consumed event from topic iris_topic: key = b8985ff1-65af-450a-b9c6-6d6082468f7c value = 6.4,2.8,5.6,2.1
#
# Consumed event from topic iris_topic: key = 667644a2-6185-4955-8fc7-e37343fe6fb5 value = 6.0,2.7,5.1,1.6
#
# Consumed event from topic iris_topic: key = 24c5808c-6755-44ae-91e1-48b400971cbc value = 4.8,3.0,1.4,0.3
#
# Consumed event from topic iris_topic: key = 91d07ce0-d9ad-4b15-a15b-14397ee3c1ed value = 5.1,3.8,1.5,0.3
#
# Consumed event from topic iris_topic: key = 5eaa3aec-104f-4a20-88e9-2e47037ac039 value = 6.1,2.8,4.7,1.2
#
# Consumed event from topic iris_topic: key = 5938aeb7-9c2b-4b89-893d-8f54feb7b2e0 value = 6.4,3.2,4.5,1.5
#
# Consumed event from topic iris_topic: key = 5e6fffb0-208d-48c3-807f-8001112dcc40 value = 6.5,3.0,5.5,1.8
#
# Consumed event from topic iris_topic: key = a19fb6c2-d05a-46ba-bfa9-fcaa316f8933 value = 7.0,3.2,4.7,1.4
#
# Consumed event from topic iris_topic: key = afc1fd67-133a-45e8-a3c4-d38733faaecf value = 4.9,3.1,1.5,0.1
#
# Consumed event from topic iris_topic: key = ef160cdc-803a-4287-b7b8-3cc325251555 value = 4.9,3.1,1.5,0.2
#
# Consumed event from topic iris_topic: key = 054b8324-c382-480a-acf3-75772ea7c3b7 value = 5.7,2.6,3.5,1.0
#
# Consumed event from topic iris_topic: key = 6e58df54-bb5f-42e8-82b4-c711cc699d7a value = 5.0,2.3,3.3,1.0
#
# Consumed event from topic iris_topic: key = 65fb11bb-465f-48e4-bdd5-a3cebcb18f30 value = 7.7,3.0,6.1,2.3
#
# Consumed event from topic iris_topic: key = 9005d861-0761-4bf8-8c79-d376206f3c70 value = 5.8,2.7,3.9,1.2
#
# Consumed event from topic iris_topic: key = fb947d37-ab28-4612-b0df-de825124a3c8 value = 6.5,3.0,5.2,2.0
#
# Waiting...
# Waiting...
# Waiting...
# Waiting...
# Waiting...
# Waiting...
# Waiting...
# Waiting...
# Waiting...
